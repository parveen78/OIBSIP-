# %% [markdown]
# ![netflix_PNG25.png](attachment:netflix_PNG25.png)

# %% [markdown]
# # The Netflix dataset has information about the Tv shows and Movies Available till 2021 .
# # The data set is collected from Fixable which is third_party Netflix engine and avaialble in free on kaggle also.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno # use for view the null/missing value

# %%
netflix=pd.read_csv(r"D:\All python project\csv folder\8. Netflix Dataset.csv")

# %%
netflix
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# **Getting some basic Information**

# %%
netflix.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
netflix.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
netflix.shape
# Out:
# (7789, 11)

# %%
netflix.size
# Out:
# 85679

# %%
netflix.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# **STEP 1. There is duplicate column in this dataset find it and delete those?**

# %%
netflix.duplicated()                 #duplicated command is use for find the duplicay in dataset in form boolean
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Length: 7789, dtype: bool

# %%
netflix[netflix.duplicated()] # so after fetching it we find two duplicate records here.
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
netflix.drop_duplicates(inplace=True)    # remove the duplicated records here inplace-true means that the data are permanent delted

# %%
netflix.shape                          # now as its clear from this duplicates records remove
# Out:
# (7787, 11)

# %% [markdown]
# **Step 2 find the missing value and show by some visualisation?**

# %%
netflix.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
msno.matrix(netflix)
# Out:
# <Axes: >

# %%
msno.heatmap(netflix)
# Out:
# <Axes: >

# %%
msno.bar(netflix)
# Out:
# <Axes: >

# %% [markdown]
# **Q1 For"House of cards",what is the show id and who is the director of show?**

# %%
netflix["Title"].isin(['House of Cards'])       # it show all the records in one column
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Name: Title, Length: 7787, dtype: bool

# %%
netflix[netflix["Title"].isin(['House of Cards'])]                # this show the result
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# **Q2 In which year highest number of the TV shows & Movies were released?show with bar graph**

# %%
netflix.dtypes                               # check the datatype of Release Date
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
netflix['Release_Date'] = netflix['Release_Date'].str.replace(',', '')
netflix['Release_Date'] = netflix['Release_Date'].str.replace(' ', '-')

# %%
netflix['Date_N'] = pd.to_datetime(netflix['Release_Date'], format="%B-%d-%Y", errors='coerce') # so it change the data type

# %%
netflix.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#        Release_Date Rating   Duration  \
# 0    August-14-2020  TV-MA  4 Seasons
# 1  December-23-2016  TV-MA     93 min
# 2  December-20-2018      R     78 min
# 3  November-16-2017  PG-13     80 min
# 4    January-1-2020  PG-13    123 min
#
# ...

# %%
netflix.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
netflix['Date_N'].dt.year.value_counts()                      # it counts the events of each every year in date column
# Out:
# Date_N
# 2019.0    2136
# 2020.0    2008
# 2018.0    1661
# 2017.0    1201
# 2016.0     432
# 2021.0     117
# 2015.0      79
# 2014.0      24
# 2011.0      13
# 2013.0      10
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %% [markdown]
# **Bar Graph**

# %%
netflix['Date_N'].dt.year.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Date_N'>

# %% [markdown]
# **How many Movie and Tv shows in this dataset?Show by bar graph**

# %%
netflix.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#        Release_Date Rating   Duration  \
# 0    August-14-2020  TV-MA  4 Seasons
# 1  December-23-2016  TV-MA     93 min
# 2  December-20-2018      R     78 min
# 3  November-16-2017  PG-13     80 min
# 4    January-1-2020  PG-13    123 min
#
# ...

# %%
netflix["Category"].value_counts()             # so in this dataset we use value_counts for check the Number of show and movie
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: count, dtype: int64

# %%
sns.countplot(data=netflix, x='Category')
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %% [markdown]
# **Show all the Movie that was released in the year 2000?**

# %% [markdown]
# *Create New column*

# %%
netflix.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#        Release_Date Rating   Duration  \
# 0    August-14-2020  TV-MA  4 Seasons
# 1  December-23-2016  TV-MA     93 min
# 2  December-20-2018      R     78 min
# 3  November-16-2017  PG-13     80 min
# 4    January-1-2020  PG-13    123 min
#
# ...

# %%
netflix["year"]=netflix['Date_N'].dt.year               # so we have to create a new year column from Date_N existing column

# %%
netflix.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#        Release_Date Rating   Duration  \
# 0    August-14-2020  TV-MA  4 Seasons
# 1  December-23-2016  TV-MA     93 min
# 2  December-20-2018      R     78 min
# 3  November-16-2017  PG-13     80 min
# 4    January-1-2020  PG-13    123 min
#
# ...

# %% [markdown]
# **Filtering**

# %%
netflix[(netflix['Category']=='Movie') & (netflix['year']==2000)]   # no movie release in the year of 2000
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, year]
# Index: []

# %%
netflix[(netflix['Category']=='Movie') & (netflix['year']==2020)].head(5)  # so this are the top 5 movie release in the year 2020
# Out:
#    Show_Id Category                          Title  \
# 4       s5    Movie                             21
# 6       s7    Movie                            122
# 14     s15    Movie                           3022
# 27     s28    Movie                         #Alive
# 28     s29    Movie  #AnneFrank - Parallel Stories
#
#                        Director  \
# 4                Robert Luketic
# 6               Yasir Al Yasiri
# 14                   John Suits
# 27                       Cho Il
# 28  Sabina Fedeli, Anna Migotto
#
#                                                  Cast        Country  \
# 4   Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 6   Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...          Egypt
# 14  Omar Epps, Kate Walsh, Miranda Cosgrove, Angus...  United States
# 27                           Yoo Ah-in, Park Shin-hye    South Korea
# 28                        Helen Mirren, Gengher Gatti          Italy
#
# ...

# %% [markdown]
# **show only the titles of all TV shows that were Realesed in india,only**

# %%
netflix.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#        Release_Date Rating   Duration  \
# 0    August-14-2020  TV-MA  4 Seasons
# 1  December-23-2016  TV-MA     93 min
# 2  December-20-2018      R     78 min
# 3  November-16-2017  PG-13     80 min
# 4    January-1-2020  PG-13    123 min
#
# ...

# %%
netflix[(netflix['Category']=='TV Show') & (netflix['Country']=='India')]['Title'] #here we filter the cateogry as Tvshow 
                                                                                   #country is india and show by title
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# **Show top 10 directors who give the highest number of tv show and movies to Netflix**

# %%
netflix.columns                               # here first i check the director column
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description', 'Date_N',
#        'year'],
#       dtype='object')

# %%
netflix['Director'].value_counts().head(10)  # so here we use value counts function for counting the director highest movies
                                             # And head is used here for top 10 Directors
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: count, dtype: int64

# %% [markdown]
# **Show all the Records Where "Category is Movie and Type is Comedies " or "Country is Unitedn Kingdom"**

# %%
netflix[(netflix['Category']=='Movie') & (netflix['Type']=='Comedies')]     # It is First condition
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %%
netflix[(netflix['Category']=='Movie') & (netflix['Type']=='Comedies')|(netflix['Country']=='United Kingdom')]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# **In how Many movies,Tom_cruise was cast?**

# %%
netflix.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#        Release_Date Rating   Duration  \
# 0    August-14-2020  TV-MA  4 Seasons
# 1  December-23-2016  TV-MA     93 min
# 2  December-20-2018      R     78 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
#
#                                          Description     Date_N    year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# ...

# %%
# Basic Fieltring
netflix[netflix['Cast']=='Tom Cruise']     # so its show us 0 result because in cast column there is lots of actors is present
                                             # in one movie
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, year]
# Index: []

# %%
netflix_new=netflix.dropna()               # in above question there is  an error hence. we drop the null value 
                                            # ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
netflix_new[netflix_new['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#         Release_Date Rating Duration                        Type  \
# 3860  January-1-2020      R  189 min  Dramas, Independent Movies
# 5071     July-1-2019      R  134 min      Classic Movies, Dramas
#
#                                             Description     Date_N    year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %% [markdown]
# **What are the different Rating defined by netflix?**

# %% [markdown]
# *NUNIQUE*

# %%
netflix['Rating'].nunique() #here is total 14 rating in this dataset
# Out:
# 14

# %% [markdown]
# *UNIQUE*

# %%
netflix['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# **How Many movies got the 'TV-14' rating,in Canada?**

# %%
netflix[(netflix['Category']=='Movie') & (netflix['Rating']=='TV-14')].shape 
# Total 1098 movies get this TV-14 rating in this  first condition......
# Out:
# (1272, 13)

# %%
netflix[(netflix['Category']=='Movie') & (netflix['Rating']=='TV-14') & (netflix['Country']=='Canada') ].shape 
# in canada 9 movies get this type of rating........
# Out:
# (11, 13)

# %% [markdown]
# **What is the maximum Duration of Movies/show on Netflix?**

# %%
netflix.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#        Release_Date Rating   Duration  \
# 0    August-14-2020  TV-MA  4 Seasons
# 1  December-23-2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
netflix['Duration'].unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
netflix[['Minutes', 'Unit']] = netflix['Duration'].str.split(' ', expand=True) 
#we specify a valid separator inside the str.split() function.

# %%
netflix.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#        Release_Date Rating   Duration  \
# 0    August-14-2020  TV-MA  4 Seasons
# 1  December-23-2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minutes     Unit
# 0       4  Seasons
# 1      93      min

# %%
netflix['Minutes']=netflix['Minutes'].astype(int) # so here we change the Data type of object from int

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7787 entries, 0 to 7788
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7787 non-null   object
#  1   Category      7787 non-null   object
#  2   Title         7787 non-null   object
#  3   Director      5399 non-null   object
#  4   Cast          7069 non-null   object
#  5   Country       7280 non-null   object
#  6   Release_Date  7777 non-null   object
#  7   Rating        7780 non-null   object
#  8   Duration      7787 non-null   object
#  9   Type          7787 non-null   object
#  10  Description   7787 non-null   object
#  11  Date_N        7689 non-null   datetime64[ns]
#  12  year          7689 non-null   float64
#  13  Minutes       7787 non-null   int32
#  14  Unit          7787 non-null   object
# dtypes: datetime64[ns](1), float64(1), int32(1), object(12)
# memory usage: 943.0+ KB

# %%
#max duration
netflix['Minutes'].max()
# Out:
# 312

# %%
#min duration
netflix['Minutes'].min()
# Out:
# 1

# %% [markdown]
# **Which individual country has the Highest No.of TV shows?**

# %%
netflix_shows=netflix[netflix['Category']=='TV Show']

# %%
netflix_shows
# Out:
#      Show_Id Category                  Title              Director  \
# 0         s1  TV Show                     3%                   NaN
# 5         s6  TV Show                     46           Serdar Akar
# 11       s12  TV Show                   1983                   NaN
# 12       s13  TV Show                   1994  Diego Enrique Osorno
# 16       s17  TV Show                 Feb-09                   NaN
# ...      ...      ...                    ...                   ...
# 7769   s7768  TV Show     Zindagi Gulzar Hai                   NaN
# 7777   s7776  TV Show             Zoids Wild                   NaN
# 7779   s7778  TV Show            Zombie Dumb                   NaN
# 7781   s7780  TV Show              Zona Rosa                   NaN
# 7787   s7786  TV Show  Zumbo's Just Desserts                   NaN
#
#                                                    Cast  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
netflix_shows.Country.value_counts()
# Out:
# Country
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: count, Length: 183, dtype: int64

# %%
netflix_shows.Country.value_counts().head(1) # Here is united states is a country in NUmber 1
# Out:
# Country
# United States    705
# Name: count, dtype: int64

# %%
netflix.shape
# Out:
# (7787, 15)

# %% [markdown]
# **How we can sort the dataset by year?**

# %%
netflix.sort_values(by='year', ascending=False).head(2)    
# Here we sort the data by Year and take ascending order as False
# Out:
#      Show_Id Category            Title                 Director  \
# 5564   s5564    Movie  Sherlock Holmes              Guy Ritchie
# 5919   s5919    Movie        Surf's Up  Ash Brannon, Chris Buck
#
#                                                    Cast  \
# 5564  Robert Downey Jr., Jude Law, Rachel McAdams, M...
# 5919  Shia LaBeouf, Jeff Bridges, Zooey Deschanel, J...
#
#                                                 Country    Release_Date  \
# 5564  United States, Germany, United Kingdom, Australia  January-1-2021
# 5919                                      United States  January-1-2021
#
#      Rating Duration                                               Type  \
# 5564  PG-13  128 min                       Action & Adventure, Comedies
# 5919     PG   86 min  Children & Family Movies, Comedies, Sports Movies
#
#                                             Description     Date_N    year  \
# 5564  The game is afoot for an eccentric detective w... 2021-01-01  2021.0
# ...

# %% [markdown]
# **Find all the instance where:**
#
#     *Category is movie and type is Dramas*
#     *or*
#     *category is Tv show and type is kid tv*

# %%
netflix[(netflix['Category']=='Movie') & (netflix['Type']=='Dramas')].head(2)
# Out:
#   Show_Id Category Title        Director  \
# 4      s5    Movie    21  Robert Luketic
# 7      s8    Movie   187  Kevin Reynolds
#
#                                                 Cast        Country  \
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 7  Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States
#
#       Release_Date Rating Duration    Type  \
# 4   January-1-2020  PG-13  123 min  Dramas
# 7  November-1-2019      R  119 min  Dramas
#
#                                          Description     Date_N    year  \
# 4  A brilliant group of students become card-coun... 2020-01-01  2020.0
# 7  After one of his high school students attacks ... 2019-11-01  2019.0
#
#    Minutes Unit
# 4      123  min
# 7      119  min

# %%
netflix[(netflix['Category']=='TV Show') & (netflix['Type']=="Kids' TV")].head(2)
# Out:
#     Show_Id Category         Title     Director  \
# 111    s112  TV Show       44 Cats          NaN
# 276    s277  TV Show  Abby Hatcher  Kyran Kelly
#
#                                                   Cast                Country  \
# 111  Sarah Natochenny, Suzy Myers, Simona Berman, E...                  Italy
# 276  Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...  United States, Canada
#
#        Release_Date Rating   Duration      Type  \
# 111  October-1-2020  TV-Y7  2 Seasons  Kids' TV
# 276     July-1-2020   TV-Y   1 Season  Kids' TV
#
#                                            Description     Date_N    year  \
# 111  Paw-esome tales abound when singing furry frie... 2020-10-01  2020.0
# 276  A big-hearted girl helps her Fuzzly friends wh... 2020-07-01  2020.0
#
#      Minutes     Unit
# 111        2  Seasons
# 276        1   Season

# %%
netflix[(netflix['Category']=='Movie') & (netflix['Type']=='Dramas')| (netflix['Category']=='TV Show') & (netflix['Type']=="Kids' TV")].head(10)
# Out:
#     Show_Id Category                           Title          Director  \
# 4        s5    Movie                              21    Robert Luketic
# 7        s8    Movie                             187    Kevin Reynolds
# 111    s112  TV Show                         44 Cats               NaN
# 170    s171    Movie                    A Family Man     Mark Williams
# 232    s233    Movie      A Stoning in Fulham County     Larry Elikann
# 276    s277  TV Show                    Abby Hatcher       Kyran Kelly
# 295    s296    Movie              Across Grace Alley     Ralph Macchio
# 308    s309    Movie        Adam: His Song Continues  Robert Markowitz
# 330    s331    Movie                       Aftermath    Elliott Lester
# 334    s335    Movie  Agatha and the Truth of Murder       Terry Loane
#
#                                                   Cast  \
# 4    Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7    Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# ...

# %% [markdown]
#  # END OF PROJECT
